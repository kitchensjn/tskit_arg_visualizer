# %%
# %%javascript
# require.config({
#     paths: {
#     d3: 'https://d3js.org/d3.v7.min'
# }});
#
# require(["d3"], function(d3) {
#     window.d3 = d3;
# });

# %%
import msprime
import random
import json
import tskit_arg_visualizer

# Generate a random tree sequence with record_full_arg=True so that you get marked recombination nodes
ts_rs = random.randint(0,10000)   
ts = msprime.sim_ancestry(
    samples=2,
    recombination_rate=1e-8,
    sequence_length=3_000,
    population_size=10_000,
    record_full_arg=True,
    random_seed=1
)

d3arg = tskit_arg_visualizer.D3ARG(ts=ts)
d3arg.draw(width=500, height=500, y_axis_labels=True, y_axis_scale="rank", tree_highlighting=True, edge_type="ortho")
# Out:
# <style>.d3arg {
#     position: relative;
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background-color: white;
#     padding: 20px 20px 60px 20px;
# }
#
# .d3arg:hover .dashboard {
#     visibility: visible;
# }
#
# .dashboard {
#     display: flex;
#     visibility: hidden;
# }
#
# .dashboard button {
#     position: relative;
#     font-size: 30px;
#     border: 0px;
#     background-color: white;
#     width: 30px;
#     height: 30px;
# }
#
# .dashboard button .tip {
#     width: 120px;
#     font-size: 12px;
#     background-color: lightgrey;
#     color: #053e4e;
#     text-align: center;
#     padding: 5px 0px;
#     position: absolute;
#     z-index: 1;
#     top: 100%;
#     left: 50%;
#     margin-left: -60px;
#     visibility: hidden;
# }
#
# .dashboard button:hover .desc {
#     visibility: visible;
# }
#
# .dashboard path {
#     fill: grey;
# }
#
# .dashboard button:hover path {
#     fill: #053e4e;
# }
#
# .dashboard button:active path {
#     fill: #1eebb1;
# }
#
# .yaxis path {
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .yaxis line {
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .yaxis text {
#     fill: #053e4e;
#     stroke: 1px;
# }
#
# .node {
#     fill: #1eebb1;
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .hiddennode {
#     fill: lightgrey;
#     stroke: lightgrey;
#     stroke-width: 3px;
# }
#
# .underlink {
#     stroke: #ffffff;
#     stroke-width: 10px;
#     fill: none;
# }
#
# .link {
#     stroke: #053e4e;
#     stroke-width: 3px;
#     fill: none;
# }
#
# .hiddenlink {
#     stroke: lightgrey;
#     stroke-width: 3px;
#     fill: none;
# }
#
# .labels {
#     text-anchor: middle;
# }
#
# .label {
#     fill: #053e4e;
#     font-family: Arial;
#     font-size: 12px;
# }
#
# .hiddenlabel {
#     fill: lightgrey;
#     font-family: Arial;
#     font-size: 12px;
# }
#
# svg {
#     display: block;
# }
#
# button {
#     display: block;
#     cursor: pointer;
# }
#
# .saving {
#     display: flex;
#     flex-direction: row;
# }
#
# .saving .message {
#     display: none;
# }</style><script src='https://d3js.org/d3.v7.min.js'></script><div id='arg_336668829'class='d3arg' style='min-width:590px; min-height:655px;'></div><script>var line = d3.line();
# var step = d3.line().curve(d3.curveStep);
# var stepAfter = d3.line().curve(d3.curveStepAfter);
# var stepBefore = d3.line().curve(d3.curveStepBefore);
#
# function draw_force_diagram() {
#
#     var graph = {'nodes': [{'id': 0, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [9], 'parent_of': [], 'label': 0, 'fx_01': 0.0, 'fx': 100.0, 'fy': 450.0, 'y': 450.0}, {'id': 1, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [4], 'parent_of': [], 'label': 1, 'fx_01': 0.3333333333333333, 'fx': 233.33333333333331, 'fy': 450.0, 'y': 450.0}, {'id': 2, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [6], 'parent_of': [], 'label': 2, 'fx_01': 0.6666666666666666, 'fx': 366.66666666666663, 'fy': 450.0, 'y': 450.0}, {'id': 3, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [7], 'parent_of': [], 'label': 3, 'fx_01': 1.0, 'fx': 500.0, 'fy': 450.0, 'y': 450.0}, {'id': 4, 'flag': 131072, 'time': 4498.214625807461, 'time_01': 0.7275563458708292, 'logtime_01': 0.1338687598448185, 'rank_01': 0.8, 'child_of': [8], 'parent_of': [1], 'x_pos_reference': 1, 'label': '4/5', 'fy': 370.0, 'y': 370.0}, {'id': 6, 'flag': 0, 'time': 4498.4434010524765, 'time_01': 0.7275424896258718, 'logtime_01': 0.13386352428209813, 'rank_01': 0.6, 'child_of': [7], 'parent_of': [2, 4], 'label': 6, 'fy': 290.0, 'y': 290.0}, {'id': 7, 'flag': 0, 'time': 5027.475391806758, 'time_01': 0.6955005750659471, 'logtime_01': 0.12241728357973047, 'rank_01': 0.3999999999999999, 'child_of': [8], 'parent_of': [3, 6], 'label': 7, 'fy': 209.99999999999997, 'y': 209.99999999999997}, {'id': 8, 'flag': 0, 'time': 6401.572951565892, 'time_01': 0.6122755199156376, 'logtime_01': 0.09754196588832187, 'rank_01': 0.19999999999999996, 'child_of': [9], 'parent_of': [4, 7], 'label': 8, 'fy': 130.0, 'y': 130.0}, {'id': 9, 'flag': 0, 'time': 16510.62360099887, 'time_01': 0.0, 'logtime_01': -6.236277918070243e-06, 'rank_01': 0.0, 'child_of': [], 'parent_of': [0, 8], 'label': 9, 'fy': 50.0, 'y': 50.0}], 'links': [{'source': 4, 'target': 1, 'left': 0.0, 'right': 2644.0, 'alt_parent': '', 'alt_child': ''}, {'source': 4, 'target': 1, 'left': 2644.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': ''}, {'source': 6, 'target': 2, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 4}, {'source': 6, 'target': 4, 'left': 2644.0, 'right': 3000.0, 'alt_parent': 8, 'alt_child': 2}, {'source': 7, 'target': 3, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 6}, {'source': 7, 'target': 6, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 3}, {'source': 8, 'target': 4, 'left': 0.0, 'right': 2644.0, 'alt_parent': 6, 'alt_child': 7}, {'source': 8, 'target': 7, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 4}, {'source': 9, 'target': 0, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 8}, {'source': 9, 'target': 8, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 0}], 'breakpoints': [{'start': 0, 'stop': 2644.0, 'x_pos_01': 0.0, 'width_01': 0.8813333333333333, 'x_pos': 50.0, 'width': 440.66666666666663}, {'start': 2644.0, 'stop': 3000.0, 'x_pos_01': 0.8813333333333333, 'width_01': 0.11866666666666667, 'x_pos': 490.66666666666663, 'width': 59.333333333333336}]};
#     var y_axis = {'include_labels': 'true', 'ticks': [450.0, 370.0, 290.0, 209.99999999999997, 130.0, 50.0], 'text': [0, 4498, 4498, 5027, 6402, 16511], 'max_min': [450.0, 50.0], 'scale': 'rank'};
#     var subset = [0, 1, 2, 3, 4, 6, 7, 8, 9];
#
#     var dashboard = d3.select("#arg_336668829").append("div").attr("class", "dashboard");
#
#     var clipboard = dashboard.append("button")
#         .on("click", function() {
#             navigator.clipboard.writeText("{'arg': {'nodes': [{'id': 0, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [9], 'parent_of': [], 'label': 0, 'fx_01': 0.0, 'fx': 100.0, 'fy': 450.0, 'y': 450.0}, {'id': 1, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [4], 'parent_of': [], 'label': 1, 'fx_01': 0.3333333333333333, 'fx': 233.33333333333331, 'fy': 450.0, 'y': 450.0}, {'id': 2, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [6], 'parent_of': [], 'label': 2, 'fx_01': 0.6666666666666666, 'fx': 366.66666666666663, 'fy': 450.0, 'y': 450.0}, {'id': 3, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [7], 'parent_of': [], 'label': 3, 'fx_01': 1.0, 'fx': 500.0, 'fy': 450.0, 'y': 450.0}, {'id': 4, 'flag': 131072, 'time': 4498.214625807461, 'time_01': 0.7275563458708292, 'logtime_01': 0.1338687598448185, 'rank_01': 0.8, 'child_of': [8], 'parent_of': [1], 'x_pos_reference': 1, 'label': '4/5', 'fy': 370.0, 'y': 370.0}, {'id': 6, 'flag': 0, 'time': 4498.4434010524765, 'time_01': 0.7275424896258718, 'logtime_01': 0.13386352428209813, 'rank_01': 0.6, 'child_of': [7], 'parent_of': [2, 4], 'label': 6, 'fy': 290.0, 'y': 290.0}, {'id': 7, 'flag': 0, 'time': 5027.475391806758, 'time_01': 0.6955005750659471, 'logtime_01': 0.12241728357973047, 'rank_01': 0.3999999999999999, 'child_of': [8], 'parent_of': [3, 6], 'label': 7, 'fy': 209.99999999999997, 'y': 209.99999999999997}, {'id': 8, 'flag': 0, 'time': 6401.572951565892, 'time_01': 0.6122755199156376, 'logtime_01': 0.09754196588832187, 'rank_01': 0.19999999999999996, 'child_of': [9], 'parent_of': [4, 7], 'label': 8, 'fy': 130.0, 'y': 130.0}, {'id': 9, 'flag': 0, 'time': 16510.62360099887, 'time_01': 0.0, 'logtime_01': -6.236277918070243e-06, 'rank_01': 0.0, 'child_of': [], 'parent_of': [0, 8], 'label': 9, 'fy': 50.0, 'y': 50.0}], 'links': [{'source': 4, 'target': 1, 'left': 0.0, 'right': 2644.0, 'alt_parent': '', 'alt_child': ''}, {'source': 4, 'target': 1, 'left': 2644.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': ''}, {'source': 6,

# %%
import msprime
import tskit_arg_visualizer


ts = msprime.sim_ancestry(
    samples=2,
    recombination_rate=1e-8,
    sequence_length=3_000,
    population_size=10_000,
    record_full_arg=True,
    random_seed=2523
)

d3arg = tskit_arg_visualizer.D3ARG(ts=ts)
d3arg.draw(edge_type="ortho")
# Out:
# <style>.d3arg {
#     position: relative;
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background-color: white;
#     padding: 20px 20px 60px 20px;
# }
#
# .d3arg:hover .dashboard {
#     visibility: visible;
# }
#
# .dashboard {
#     display: flex;
#     visibility: hidden;
# }
#
# .dashboard button {
#     position: relative;
#     font-size: 30px;
#     border: 0px;
#     background-color: white;
#     width: 30px;
#     height: 30px;
# }
#
# .dashboard button .tip {
#     width: 120px;
#     font-size: 12px;
#     background-color: lightgrey;
#     color: #053e4e;
#     text-align: center;
#     padding: 5px 0px;
#     position: absolute;
#     z-index: 1;
#     top: 100%;
#     left: 50%;
#     margin-left: -60px;
#     visibility: hidden;
# }
#
# .dashboard button:hover .desc {
#     visibility: visible;
# }
#
# .dashboard path {
#     fill: grey;
# }
#
# .dashboard button:hover path {
#     fill: #053e4e;
# }
#
# .dashboard button:active path {
#     fill: #1eebb1;
# }
#
# .yaxis path {
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .yaxis line {
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .yaxis text {
#     fill: #053e4e;
#     stroke: 1px;
# }
#
# .node {
#     fill: #1eebb1;
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .hiddennode {
#     fill: lightgrey;
#     stroke: lightgrey;
#     stroke-width: 3px;
# }
#
# .underlink {
#     stroke: #ffffff;
#     stroke-width: 10px;
#     fill: none;
# }
#
# .link {
#     stroke: #053e4e;
#     stroke-width: 3px;
#     fill: none;
# }
#
# .hiddenlink {
#     stroke: lightgrey;
#     stroke-width: 3px;
#     fill: none;
# }
#
# .labels {
#     text-anchor: middle;
# }
#
# .label {
#     fill: #053e4e;
#     font-family: Arial;
#     font-size: 12px;
# }
#
# .hiddenlabel {
#     fill: lightgrey;
#     font-family: Arial;
#     font-size: 12px;
# }
#
# svg {
#     display: block;
# }
#
# button {
#     display: block;
#     cursor: pointer;
# }
#
# .saving {
#     display: flex;
#     flex-direction: row;
# }
#
# .saving .message {
#     display: none;
# }</style><script src='https://d3js.org/d3.v7.min.js'></script><div id='arg_9136774067'class='d3arg' style='min-width:590px; min-height:655px;'></div><script>var line = d3.line();
# var step = d3.line().curve(d3.curveStep);
# var stepAfter = d3.line().curve(d3.curveStepAfter);
# var stepBefore = d3.line().curve(d3.curveStepBefore);
#
# function draw_force_diagram() {
#
#     var graph = {'nodes': [{'id': 0, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [5], 'parent_of': [], 'label': 0, 'fx_01': 0.0, 'fx': 100.0, 'fy': 450.0, 'y': 450.0}, {'id': 1, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [9], 'parent_of': [], 'label': 1, 'fx_01': 0.3333333333333333, 'fx': 233.33333333333331, 'fy': 450.0, 'y': 450.0}, {'id': 2, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [4], 'parent_of': [], 'label': 2, 'fx_01': 0.6666666666666666, 'fx': 366.66666666666663, 'fy': 450.0, 'y': 450.0}, {'id': 3, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [4], 'parent_of': [], 'label': 3, 'fx_01': 1.0, 'fx': 500.0, 'fy': 450.0, 'y': 450.0}, {'id': 4, 'flag': 0, 'time': 1957.2580626282304, 'time_01': 0.9357645185132406, 'logtime_01': 0.2658423098091435, 'rank_01': 0.8571428571428572, 'child_of': [11], 'parent_of': [2, 3], 'label': 4, 'fy': 392.8571428571429, 'y': 392.8571428571429}, {'id': 5, 'flag': 131072, 'time': 3784.5660859945174, 'time_01': 0.8757938825778161, 'logtime_01': 0.20199997928855262, 'rank_01': 0.7142857142857143, 'child_of': [12], 'parent_of': [0], 'x_pos_reference': 0, 'label': '5/6', 'fy': 335.7142857142857, 'y': 335.7142857142857}, {'id': 7, 'flag': 131072, 'time': 6390.972547359223, 'time_01': 0.7902539237993891, 'logtime_01': 0.15126168598141843, 'rank_01': 0.5714285714285714, 'child_of': [10], 'parent_of': [5], 'x_pos_reference': 5, 'label': '7/8', 'fy': 278.57142857142856, 'y': 278.57142857142856}, {'id': 9, 'flag': 0, 'time': 7786.248160010931, 'time_01': 0.7444622101277314, 'logtime_01': 0.13213779204667275, 'rank_01': 0.4285714285714286, 'child_of': [10], 'parent_of': [1, 7], 'label': 9, 'fy': 221.42857142857144, 'y': 221.42857142857144}, {'id': 10, 'flag': 0, 'time': 7925.631708857819, 'time_01': 0.7398877651209802, 'logtime_01': 0.1304194861801362, 'rank_01': 0.2857142857142858, 'child_of': [11], 'parent_of': [7, 9], 'label': 10, 'fy': 164.28571428571433, 'y': 164.28571428571433}, {'id': 11, 'flag': 0, 'time': 17084.027332180816, 'time_01': 0.43931730701776306, 'logtime_01': 0.05603580276664555, 'rank_01': 0.1428571428571429, 'child_of': [12], 'parent_of': [4, 10], 'label': 11, 'fy': 107.14285714285717, 'y': 107.14285714285717}, {'id': 12, 'flag': 0, 'time': 30470.045795977614, 'time_01': 0.0, 'logtime_01': -3.178708946505182e-06, 'rank_01': 0.0, 'child_of': [], 'parent_of': [5, 11], 'label': 12, 'fy': 50.0, 'y': 50.0}], 'links': [{'source': 4, 'target': 2, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 3}, {'source': 4, 'target': 3, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 2}, {'source': 5, 'target': 0, 'left': 0.0, 'right': 201.0, 'alt_parent': '', 'alt_child': ''}, {'source': 5, 'target': 0, 'left': 201.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': ''}, {'source': 7, 'target': 5, 'left': 201.0, 'right': 1991.0, 'alt_parent': 12, 'alt_child': ''}, {'source': 7, 'target': 5, 'left': 1991.0, 'right': 3000.0, 'alt_parent': 12, 'alt_child': ''}, {'source': 9, 'target': 1, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 7}, {'source': 9, 'target': 7, 'left': 1991.0, 'right': 3000.0, 'alt_parent': 10, 'alt_child': 1}, {'source': 10, 'target': 7, 'left': 201.0, 'right': 1991.0, 'alt_parent': 9, 'alt_child': 9}, {'source': 10, 'target': 9, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 7}, {'source': 11, 'target': 4, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 10}, {'source': 11, 'target': 10, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 4}, {'source': 12, 'target': 5, 'left': 0.0, 'right': 201.0, 'alt_parent': 7, 'alt_child': 11}, {'source': 12, 'target': 11, 'left': 0.0, 'right': 201.0, 'alt_parent': '', 'alt_child': 5}], 'breakpoints': [{'start': 0, 'stop': 201.0, 'x_pos_01': 0.0, 'width_01': 0.067, 'x_pos': 50.0, 'width': 33.5}, {'start ...
#     var y_axis = {'include_labels': 'true', 'ticks': [450.0, 392.8571428571429, 335.7142857142857, 278.57142857142856, 221.42857142857144, 164.28571428571433, 107.14285714285717, 50.0], 'text': [0, 1957, 3785, 6391, 7786, 7926, 17084, 30470], 'max_min': [450.0, 50.0], 'scale': 'rank'};
#     var subset = [0, 1, 2, 3, 4, 5, 7, 9, 10, 11, 12];
#
#     var dashboard = d3.select("#arg_9136774067").append("div").attr("class", "dashboard");
#
#     var clipboard = dashboard.append("button")
#         .on("click", function() {
#             navigator.clipboard.writeText("{'arg': {'nodes': [{'id': 0, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [5], 'parent_of': [], 'label': 0, 'fx_01': 0.0, 'fx': 100.0, 'fy': 450.0, 'y': 450.0}, {'id': 1, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [9], 'parent_of': [], 'label': 1, 'fx_01': 0.3333333333333333, 'fx': 233.33333333333331, 'fy': 450.0, 'y': 450.0}, {'id': 2, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [4], 'parent_of': [], 'label': 2, 'fx_01': 0.6666666666666666, 'fx': 366.66666666666663, 'fy': 450.0, 'y': 450.0}, {'id': 3, 'flag': 1, 'time': 0.0, 'time_01': 1.0, 'logtime_01': 1.0, 'rank_01': 1.0, 'child_of': [4], 'parent_of': [], 'label': 3, 'fx_01': 1.0, 'fx': 500.0, 'fy': 450.0, 'y': 450.0}, {'id': 4, 'flag': 0, 'time': 1957.2580626282304, 'time_01': 0.9357645185132406, 'logtime_

# %%
import json
import tskit_arg_visualizer

arg_json = json.load(open("example.json", "r"))
tskit_arg_visualizer.draw_D3(arg_json=arg_json)
# Out:
# <style>.d3arg {
#     position: relative;
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background-color: white;
#     padding: 20px 20px 60px 20px;
# }
#
# .d3arg:hover .dashboard {
#     visibility: visible;
# }
#
# .dashboard {
#     display: flex;
#     visibility: hidden;
# }
#
# .dashboard button {
#     position: relative;
#     font-size: 30px;
#     border: 0px;
#     background-color: white;
#     width: 30px;
#     height: 30px;
# }
#
# .dashboard button .tip {
#     width: 120px;
#     font-size: 12px;
#     background-color: lightgrey;
#     color: #053e4e;
#     text-align: center;
#     padding: 5px 0px;
#     position: absolute;
#     z-index: 1;
#     top: 100%;
#     left: 50%;
#     margin-left: -60px;
#     visibility: hidden;
# }
#
# .dashboard button:hover .desc {
#     visibility: visible;
# }
#
# .dashboard path {
#     fill: grey;
# }
#
# .dashboard button:hover path {
#     fill: #053e4e;
# }
#
# .dashboard button:active path {
#     fill: #1eebb1;
# }
#
# .yaxis path {
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .yaxis line {
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .yaxis text {
#     fill: #053e4e;
#     stroke: 1px;
# }
#
# .node {
#     fill: #1eebb1;
#     stroke: #053e4e;
#     stroke-width: 3px;
# }
#
# .hiddennode {
#     fill: lightgrey;
#     stroke: lightgrey;
#     stroke-width: 3px;
# }
#
# .underlink {
#     stroke: #ffffff;
#     stroke-width: 10px;
#     fill: none;
# }
#
# .link {
#     stroke: #053e4e;
#     stroke-width: 3px;
#     fill: none;
# }
#
# .hiddenlink {
#     stroke: lightgrey;
#     stroke-width: 3px;
#     fill: none;
# }
#
# .labels {
#     text-anchor: middle;
# }
#
# .label {
#     fill: #053e4e;
#     font-family: Arial;
#     font-size: 12px;
# }
#
# .hiddenlabel {
#     fill: lightgrey;
#     font-family: Arial;
#     font-size: 12px;
# }
#
# svg {
#     display: block;
# }
#
# button {
#     display: block;
#     cursor: pointer;
# }
#
# .saving {
#     display: flex;
#     flex-direction: row;
# }
#
# .saving .message {
#     display: none;
# }</style><script src='https://d3js.org/d3.v7.min.js'></script><div id='arg_3433931212'class='d3arg' style='min-width:590px; min-height:655px;'></div><script>var line = d3.line();
# var step = d3.line().curve(d3.curveStep);
# var stepAfter = d3.line().curve(d3.curveStepAfter);
# var stepBefore = d3.line().curve(d3.curveStepBefore);
#
# function draw_force_diagram() {
#
#     var graph = {'nodes': [{'id': 0, 'flag': 1, 'time': 0, 'time_01': 1, 'logtime_01': 1, 'rank_01': 1, 'child_of': [5], 'parent_of': [], 'label': 0, 'fx_01': 0, 'fx': 100, 'fy': 450, 'y': 450, 'index': 0, 'x': 100, 'vy': 0, 'vx': 0}, {'id': 1, 'flag': 1, 'time': 0, 'time_01': 1, 'logtime_01': 1, 'rank_01': 1, 'child_of': [9], 'parent_of': [], 'label': 1, 'fx_01': 0.3333333333333333, 'fx': 233.33333333333331, 'fy': 450, 'y': 450, 'index': 1, 'x': 233.33333333333331, 'vy': 0, 'vx': 0}, {'id': 2, 'flag': 1, 'time': 0, 'time_01': 1, 'logtime_01': 1, 'rank_01': 1, 'child_of': [4], 'parent_of': [], 'label': 2, 'fx_01': 0.6666666666666666, 'fx': 366.66666666666663, 'fy': 450, 'y': 450, 'index': 2, 'x': 366.66666666666663, 'vy': 0, 'vx': 0}, {'id': 3, 'flag': 1, 'time': 0, 'time_01': 1, 'logtime_01': 1, 'rank_01': 1, 'child_of': [4], 'parent_of': [], 'label': 3, 'fx_01': 1, 'fx': 500, 'fy': 450, 'y': 450, 'index': 3, 'x': 500, 'vy': 0, 'vx': 0}, {'id': 4, 'flag': 0, 'time': 1957.2580626282304, 'time_01': 0.9357645185132406, 'logtime_01': 0.2658423098091435, 'rank_01': 0.8571428571428572, 'child_of': [11], 'parent_of': [2, 3], 'label': 4, 'fy': 392.8571428571429, 'y': 392.8571428571429, 'index': 4, 'x': 433.9778378334851, 'vy': 0, 'vx': 0, 'fx': 433.9778378334851}, {'id': 5, 'flag': 131072, 'time': 3784.5660859945174, 'time_01': 0.8757938825778161, 'logtime_01': 0.20199997928855262, 'rank_01': 0.7142857142857143, 'child_of': [12], 'parent_of': [0], 'x_pos_reference': 0, 'label': '5/6', 'fy': 335.7142857142857, 'y': 335.7142857142857, 'index': 5, 'x': 100, 'vy': 0, 'vx': 0, 'fx': 0.6761710025897969}, {'id': 7, 'flag': 131072, 'time': 6390.972547359223, 'time_01': 0.7902539237993891, 'logtime_01': 0.15126168598141843, 'rank_01': 0.5714285714285714, 'child_of': [10], 'parent_of': [5], 'x_pos_reference': 5, 'label': '7/8', 'fy': 278.57142857142856, 'y': 278.57142857142856, 'index': 6, 'x': 146.0340729888315, 'vy': 0, 'vx': -5.120370794031714e-12}, {'id': 9, 'flag': 0, 'time': 7786.248160010931, 'time_01': 0.7444622101277314, 'logtime_01': 0.13213779204667275, 'rank_01': 0.4285714285714286, 'child_of': [10], 'parent_of': [1, 7], 'label': 9, 'fy': 221.42857142857144, 'y': 221.42857142857144, 'index': 7, 'x': 204.98852193970353, 'vy': 0, 'vx': 0, 'fx': 204.98852193970353}, {'id': 10, 'flag': 0, 'time': 7925.631708857819, 'time_01': 0.7398877651209802, 'logtime_01': 0.1304194861801362, 'rank_01': 0.2857142857142858, 'child_of': [11], 'parent_of': [7, 9], 'label': 10, 'fy': 164.28571428571433, 'y': 164.28571428571433, 'index': 8, 'x': 166.19954040897346, 'vy': 0, 'vx': 0, 'fx': 166.19954040897346}, {'id': 11, 'flag': 0, 'time': 17084.027332180816, 'time_01': 0.43931730701776306, 'logtime_01': 0.05603580276664555, 'rank_01': 0.1428571428571429, 'child_of': [12], 'parent_of': [4, 10], 'label': 11, 'fy': 107.14285714285717, 'y': 107.14285714285717, 'index': 9, 'x': 258.90861721298984, 'vy': 0, 'vx': -3.950516372364099e-11}, {'id': 12, 'flag': 0, 'time': 30470.045795977614, 'time_01': 0, 'logtime_01': -3.178708946505182e-06, 'rank_01': 0, 'child_of': [], 'parent_of': [5, 11], 'label': 12, 'fy': 50, 'y': 50, 'index': 10, 'x': 169.49333804875366, 'vy': 0, 'vx': 2.6463363791973115e-11}], 'links': [{'source': 4, 'target': 2, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 3}, {'source': 4, 'target': 3, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 2}, {'source': 5, 'target': 0, 'left': 0.0, 'right': 201.0, 'alt_parent': '', 'alt_child': ''}, {'source': 5, 'target': 0, 'left': 201.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': ''}, {'source': 7, 'target': 5, 'left': 201.0, 'right': 1991.0, 'alt_parent': 12, 'alt_child': ''}, {'source': 7, 'target': 5, 'left': 1991.0, 'right': 3000.0, 'alt_parent': 12, 'alt_child': ''}, {'source': 9, 'target': 1, 'left': 0.0, 'right': 3000.0, 'alt_parent': '', 'alt_child': 7}, {'source': 9, 'target': 7, 'left': 1991.0, 'right': 3000.0, 'alt_parent': 10, 'alt_child': 1}, {'source': 10, 'ta ...
#     var y_axis = {'include_labels': 'true', 'ticks': [450.0, 392.8571428571429, 335.7142857142857, 278.57142857142856, 221.42857142857144, 164.28571428571433, 107.14285714285717, 50.0], 'text': [0, 1957, 3785, 6391, 7786, 7926, 17084, 30470], 'max_min': [450.0, 50.0], 'scale': 'rank'};
#     var subset = [0, 1, 2, 3, 4, 5, 7, 9, 10, 11, 12];
#
#     var dashboard = d3.select("#arg_3433931212").append("div").attr("class", "dashboard");
#
#     var clipboard = dashboard.append("button")
#         .on("click", function() {
#             navigator.clipboard.writeText("{'arg': {'nodes': [{'id': 0, 'flag': 1, 'time': 0, 'time_01': 1, 'logtime_01': 1, 'rank_01': 1, 'child_of': [5], 'parent_of': [], 'label': 0, 'fx_01': 0, 'fx': 100, 'fy': 450, 'y': 450, 'index': 0, 'x': 100, 'vy': 0, 'vx': 0}, {'id': 1, 'f

# %%
# %%javascript
# require.config({
#     paths: {
#     d3: 'https://d3js.org/d3.v7.min'
# }});
#
# require(["d3"], function(d3) {
#     window.d3 = d3;
# });

# %%
# %%javascript
# var script = document.createElement('script');
# script.type = 'text/javascript';
# script.src = 'https://d3js.org/d3.v7.min';
# document.head.appendChild(script);
